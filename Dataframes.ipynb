# %% [markdown]
# ### Dataframes

# %%
import pandas as pd
import numpy as nm
from pandas import DataFrame,Series

# %%
import  webbrowser

# %%
website = 'http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html'

# %%
webbrowser.open(website)
# Out:
# True

# %%
df = pd.read_clipboard()

# %%
df
# Out:
# Empty DataFrame
# Columns: [float(input())]
# Index: []

# %%
data = pd.read_csv(r'C:\Users\lenovo\Desktop\ExcelR\CSV files\Universities.csv')

# %%
data
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data1 = pd.read_csv(r'C:\Users\lenovo\Desktop\ExcelR\CSV files\Universities.csv',nrows=5)
data1
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88
# 4   Cornell  1280     83      33       13     21864        90

# %%
data2 = pd.read_csv(r'C:\Users\lenovo\Desktop\ExcelR\CSV files\Universities.csv',usecols=[1,4])
data2
# Out:
#      SAT  SFRatio
# 0   1310       13
# 1   1415        6
# 2   1260        9
# 3   1310       12
# 4   1280       13
# 5   1340       10
# 6   1315       12
# 7   1255       12
# 8   1400       11
# 9   1305        7
# 10  1380       10
# 11  1260       11
# 12  1255       13
# 13  1081       18
# 14  1375        8
# 15  1005       19
# 16  1360       12
# 17  1075       25
# 18  1240       17
# 19  1290       13
# 20  1180       16
# 21  1285       11
# 22  1225       14
# 23  1085       15
# 24  1375       11

# %%
data.columns
# Out:
# Index(['Univ', 'SAT', 'Top10', 'Accept', 'SFRatio', 'Expenses', 'GradRate'], dtype='object')

# %%
data['Univ']
# Out:
# 0            Brown
# 1          CalTech
# 2              CMU
# 3         Columbia
# 4          Cornell
# 5        Dartmouth
# 6             Duke
# 7       Georgetown
# 8          Harvard
# 9     JohnsHopkins
# 10             MIT
# 11    Northwestern
# 12       NotreDame
# 13       PennState
# 14       Princeton
# 15          Purdue
# 16        Stanford
# 17        TexasA&M
# 18      UCBerkeley
# 19        UChicago
# 20       UMichigan
# 21           UPenn
# 22             UVA
# 23      UWisconsin
# 24            Yale
# Name: Univ, dtype: object

# %%
data[['SAT','Accept']]
# Out:
#      SAT  Accept
# 0   1310      22
# 1   1415      25
# 2   1260      59
# 3   1310      24
# 4   1280      33
# 5   1340      23
# 6   1315      30
# 7   1255      24
# 8   1400      14
# 9   1305      44
# 10  1380      30
# 11  1260      39
# 12  1255      42
# 13  1081      54
# 14  1375      14
# 15  1005      90
# 16  1360      20
# 17  1075      67
# 18  1240      40
# 19  1290      50
# 20  1180      68
# 21  1285      36
# 22  1225      44
# 23  1085      69
# 24  1375      19

# %%
data.head()
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88
# 4   Cornell  1280     83      33       13     21864        90

# %%
data.tail()
# Out:
#           Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 20   UMichigan  1180     65      68       16     15470        85
# 21       UPenn  1285     80      36       11     27553        90
# 22         UVA  1225     77      44       14     13349        92
# 23  UWisconsin  1085     40      69       15     11857        71
# 24        Yale  1375     95      19       11     43514        96

# %%
data.iloc[2]
# Out:
# Univ          CMU
# SAT          1260
# Top10          62
# Accept         59
# SFRatio         9
# Expenses    25026
# GradRate       72
# Name: 2, dtype: object

# %%
data.iloc[2:4]
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88

# %%
data = pd.read_csv(r'C:\Users\lenovo\Desktop\ExcelR\CSV files\Universities.csv',index_col='Univ')
data
# Out:
#                SAT  Top10  Accept  SFRatio  Expenses  GradRate
# Univ
# Brown         1310     89      22       13     22704        94
# CalTech       1415    100      25        6     63575        81
# CMU           1260     62      59        9     25026        72
# Columbia      1310     76      24       12     31510        88
# Cornell       1280     83      33       13     21864        90
# Dartmouth     1340     89      23       10     32162        95
# Duke          1315     90      30       12     31585        95
# Georgetown    1255     74      24       12     20126        92
# Harvard       1400     91      14       11     39525        97
# JohnsHopkins  1305     75      44        7     58691        87
# MIT           1380     94      30       10     34870        91
# Northwestern  1260     85      39       11     28052        89
# NotreDame     1255     81      42       13     15122        94
# PennState     1081     38      54       18     10185        80
# ...

# %%
data.loc['Purdue']
# Out:
# SAT         1005
# Top10         28
# Accept        90
# SFRatio       19
# Expenses    9066
# GradRate      69
# Name: Purdue, dtype: int64

# %%
data.iloc[2]
# Out:
# SAT          1260
# Top10          62
# Accept         59
# SFRatio         9
# Expenses    25026
# GradRate       72
# Name: CMU, dtype: int64

# %%
data.iloc[2:5]
# Out:
#            SAT  Top10  Accept  SFRatio  Expenses  GradRate
# Univ
# CMU       1260     62      59        9     25026        72
# Columbia  1310     76      24       12     31510        88
# Cornell   1280     83      33       13     21864        90

# %%
data.loc[['CMU','MIT']]
# Out:
#        SAT  Top10  Accept  SFRatio  Expenses  GradRate
# Univ
# CMU   1260     62      59        9     25026        72
# MIT   1380     94      30       10     34870        91

# %%
data.loc['CMU':'MIT']
# Out:
#                SAT  Top10  Accept  SFRatio  Expenses  GradRate
# Univ
# CMU           1260     62      59        9     25026        72
# Columbia      1310     76      24       12     31510        88
# Cornell       1280     83      33       13     21864        90
# Dartmouth     1340     89      23       10     32162        95
# Duke          1315     90      30       12     31585        95
# Georgetown    1255     74      24       12     20126        92
# Harvard       1400     91      14       11     39525        97
# JohnsHopkins  1305     75      44        7     58691        87
# MIT           1380     94      30       10     34870        91

# %%
data.shape
# Out:
# (25, 6)

# %%
x = data.drop('Yale')
x
# Out:
#                SAT  Top10  Accept  SFRatio  Expenses  GradRate
# Univ
# Brown         1310     89      22       13     22704        94
# CalTech       1415    100      25        6     63575        81
# CMU           1260     62      59        9     25026        72
# Columbia      1310     76      24       12     31510        88
# Cornell       1280     83      33       13     21864        90
# Dartmouth     1340     89      23       10     32162        95
# Duke          1315     90      30       12     31585        95
# Georgetown    1255     74      24       12     20126        92
# Harvard       1400     91      14       11     39525        97
# JohnsHopkins  1305     75      44        7     58691        87
# MIT           1380     94      30       10     34870        91
# Northwestern  1260     85      39       11     28052        89
# NotreDame     1255     81      42       13     15122        94
# PennState     1081     38      54       18     10185        80
# ...

# %%
x.shape
# Out:
# (24, 6)

# %%
y = data.drop('SAT',axis=1)
y
# Out:
#               Top10  Accept  SFRatio  Expenses  GradRate
# Univ
# Brown            89      22       13     22704        94
# CalTech         100      25        6     63575        81
# CMU              62      59        9     25026        72
# Columbia         76      24       12     31510        88
# Cornell          83      33       13     21864        90
# Dartmouth        89      23       10     32162        95
# Duke             90      30       12     31585        95
# Georgetown       74      24       12     20126        92
# Harvard          91      14       11     39525        97
# JohnsHopkins     75      44        7     58691        87
# MIT              94      30       10     34870        91
# Northwestern     85      39       11     28052        89
# NotreDame        81      42       13     15122        94
# PennState        38      54       18     10185        80
# Princeton        91      14        8     30220        95
# ...

# %%
y.shape
# Out:
# (25, 5)

# %%
data.sum()
# Out:
# SAT          31661
# Top10         1912
# Accept         980
# SFRatio        318
# Expenses    684700
# GradRate      2168
# dtype: int64

# %%
data.sum(axis=1)
# Out:
# Univ
# Brown           24232
# CalTech         65202
# CMU             26488
# Columbia        33020
# Cornell         23363
# Dartmouth       33719
# Duke            33127
# Georgetown      21583
# Harvard         41138
# JohnsHopkins    60209
# MIT             36475
# Northwestern    29536
# NotreDame       16607
# PennState       11456
# Princeton       31803
# Purdue          10277
# Stanford        38025
# TexasA&M         9987
# UCBerkeley      16610
# UChicago        39895
# UMichigan       16884
# UPenn           29055
# UVA             14801
# UWisconsin      13137
# Yale            45110
# dtype: int64

# %%
data.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %%
dfr = DataFrame([[1,2,3],[nm.nan,5,6],[7,nm.nan,9],[nm.nan,nm.nan,nm.nan]])
dfr
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  NaN  5.0  6.0
# 2  7.0  NaN  9.0
# 3  NaN  NaN  NaN

# %%
# drop the NaN value from rows
new_frame = dfr.dropna()
new_frame
# Out:
#      0    1    2
# 0  1.0  2.0  3.0

# %%
# drop the rows having NaN values in all columns
n_df = dfr.dropna(how='all')
n_df
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  NaN  5.0  6.0
# 2  7.0  NaN  9.0

# %%
df1 = dfr.dropna(axis=1)
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
# Drop the rows having atleast two NaN values

dfr.dropna(thresh=2)
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  NaN  5.0  6.0
# 2  7.0  NaN  9.0

# %%
dfr.fillna(1)
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  1.0  5.0  6.0
# 2  7.0  1.0  9.0
# 3  1.0  1.0  1.0

# %% [markdown]
# ### Distribution Plots

# %%
# To ignore all warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(data['Top10'])

# %%
sns.scatterplot(x='SAT',y='Accept',data=data)

# %%
sns.pairplot(data)
