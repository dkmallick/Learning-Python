# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\lenovo\Downloads\pokemon_data.csv')
data
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
data['Total'] = data.iloc[:,4:10].sum(axis=1)
data
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
cols = list(data.columns)

# %%
data_new = data[cols[0:10] + [cols[-1]] + cols[10:12]]
data_new
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary
# 0         65       65     45    318           1      False
# ...

# %% [markdown]
# ### Save the data

# %%
# saving as csv file
data_new.to_csv('Modified_Pokemon_data.csv',index=False)

# %%
# saving as excel file
data_new.to_excel('Modified_Pokemon_data.xlsx',index=False)

# %%
# saving as text file
data_new.to_csv('Modified_Pokemon_data.txt', index=False, sep='\t')

# %% [markdown]
# ### Filtering Data

# %%
df = data_new.copy()
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary
# 0         65       65     45    318           1      False
# ...

# %%
df.loc[df['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary
# ...

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
df_filtered = df.loc[((df['Type 1'] == 'Grass') | (df['Type 1'] == 'Fire')) & (df['Attack'] > 50)\
                    & (df['Defense'] > 50)]
df_filtered
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 5      5             Charmeleon   Fire     NaN   58      64       58       80
# 6      6              Charizard   Fire  Flying   78      84       78      109
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 730  662            Fletchinder   Fire  Flying   62      73       55       56
# 731  663             Talonflame   Fire  Flying   78      81       71       74
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
# Reset Index

dff = df_filtered.reset_index()
dff
# Out:
#     index    #                   Name Type 1  Type 2   HP  Attack  Defense  \
# 0       1    2                Ivysaur  Grass  Poison   60      62       63
# 1       2    3               Venusaur  Grass  Poison   80      82       83
# 2       3    3  VenusaurMega Venusaur  Grass  Poison   80     100      123
# 3       5    5             Charmeleon   Fire     NaN   58      64       58
# 4       6    6              Charizard   Fire  Flying   78      84       78
# ..    ...  ...                    ...    ...     ...  ...     ...      ...
# 75    730  662            Fletchinder   Fire  Flying   62      73       55
# 76    731  663             Talonflame   Fire  Flying   78      81       71
# 77    736  668                 Pyroar   Fire  Normal   86      68       72
# 78    741  673                 Gogoat  Grass     NaN  123     100       62
# 79    799  721              Volcanion   Fire   Water   80     110      120
#
#     Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary
# ...

# %%
dff = df_filtered.reset_index(drop=True)
dff
# Out:
#       #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0     2                Ivysaur  Grass  Poison   60      62       63       80
# 1     3               Venusaur  Grass  Poison   80      82       83      100
# 2     3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 3     5             Charmeleon   Fire     NaN   58      64       58       80
# 4     6              Charizard   Fire  Flying   78      84       78      109
# ..  ...                    ...    ...     ...  ...     ...      ...      ...
# 75  662            Fletchinder   Fire  Flying   62      73       55       56
# 76  663             Talonflame   Fire  Flying   78      81       71       74
# 77  668                 Pyroar   Fire  Normal   86      68       72      109
# 78  673                 Gogoat  Grass     NaN  123     100       62       97
# 79  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
df_filtered.reset_index(drop=True,inplace=True)
df_filtered
# Out:
#       #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0     2                Ivysaur  Grass  Poison   60      62       63       80
# 1     3               Venusaur  Grass  Poison   80      82       83      100
# 2     3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 3     5             Charmeleon   Fire     NaN   58      64       58       80
# 4     6              Charizard   Fire  Flying   78      84       78      109
# ..  ...                    ...    ...     ...  ...     ...      ...      ...
# 75  662            Fletchinder   Fire  Flying   62      73       55       56
# 76  663             Talonflame   Fire  Flying   78      81       71       74
# 77  668                 Pyroar   Fire  Normal   86      68       72      109
# 78  673                 Gogoat  Grass     NaN  123     100       62       97
# 79  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %% [markdown]
# ### Conditional Changes

# %%
df.loc[df['Type 1'] == 'Fire', 'Type 1' ] = 'Flamer'
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander   Flamer     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion   Flamer   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary
# 0         65       65     45    318           1      False
# ...

# %%
df.loc[df['Type 1'] == 'Flamer', 'Legendary'] = True
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander   Flamer     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion   Flamer   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary
# 0         65       65     45    318           1      False
# ...

# %%
df.loc[df['Total'] > 500, ['Generation','Legendary']] = ['Test 1','Test 2']
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander   Flamer     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion   Flamer   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total Generation Legendary
# 0         65       65     45    318          1     False
# ...

# %% [markdown]
# ### Aggregate Statistics (Groupby)

# %%
df = data_new.copy()

# %%
df.groupby('Type 1').mean().sort_values('Defense', ascending=False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# ...

# %%
df.groupby('Type 1').count()
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug        69    69      52   69      69       69       69       69     69
# Dark       31    31      21   31      31       31       31       31     31
# Dragon     32    32      21   32      32       32       32       32     32
# Electric   44    44      17   44      44       44       44       44     44
# Fairy      17    17       2   17      17       17       17       17     17
# Fighting   27    27       7   27      27       27       27       27     27
# Fire       52    52      24   52      52       52       52       52     52
# Flying      4     4       2    4       4        4        4        4      4
# Ghost      32    32      22   32      32       32       32       32     32
# Grass      70    70      37   70      70       70       70       70     70
# Ground     32    32      19   32      32       32       32       32     32
# ...

# %%
df['count'] =1
df.groupby('Type 1').count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary  count
# ...

# %% [markdown]
# ### Working with large amount of data

# %%
df = data_new.copy()

# %%
for df in pd.read_csv(r'C:\Users\lenovo\Desktop\Basics of Python\Modified_Pokemon_data.csv', chunksize = 50):
    print('Chunk df')
    print(df)
# Out:
# Chunk df
#      #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 0    1                  Bulbasaur     Grass  Poison   45      49       49
# 1    2                    Ivysaur     Grass  Poison   60      62       63
# 2    3                   Venusaur     Grass  Poison   80      82       83
# 3    3      VenusaurMega Venusaur     Grass  Poison   80     100      123
# 4    4                 Charmander      Fire     NaN   39      52       43
# 5    5                 Charmeleon      Fire     NaN   58      64       58
# 6    6                  Charizard      Fire  Flying   78      84       78
# 7    6  CharizardMega Charizard X      Fire  Dragon   78     130      111
# 8    6  CharizardMega Charizard Y      Fire  Flying   78     104       78
# 9    7                   Squirtle     Water     NaN   44      48       65
# 10   8                  Wartortle     Water     NaN   59      63       80
# ...
